# %%
import plistlib
from PIL import Image
from tkinter import *

fileName = "./f3_fx_entropicdecay.plist"
pl = dict()
with open(fileName, 'rb') as fp:
    pl = plistlib.load(fp)
    
    # print(type(pl))
    
    # #pp(pl)
    # #print(pl['frames'])
    # for fxbox in pl.values():
    #     print(type(fxbox))
    #     for framinof in fxbox.items():
    #         #pp(fxbox)
    #         #print(type(framinof))
    #         #framinof.
    #         print(framinof)

    
for key, val in pl['metadata'].items():
    print("key = {key}, value={value}".format(key=key,value=val))
    
for item in pl['frames'].values():
    for key, val in item.items() : 
        print("key = {key}, value={value}".format(key=key,value=val))
    
window = Tk()
window.title("plist gui")
window.geometry("800x800")
window.mainloop()
#widgets.IntSlider()
# Out:
# key = format, value=2
# key = size, value={512,1024}
# key = textureFileName, value=f3_fx_entropicdecay.png
# key = frame, value={{101,606},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{303,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{303,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,909},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,808},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,707},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,606},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,505},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,404},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,303},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,909},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,808},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,707},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{303,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,505},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,404},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,303},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,909},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,808},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,707},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,606},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,505},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,404},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,303},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}

# %%
import pyglet

# pick an animated gif file you have in the working directory
ag_file = "skull.gif"
animation = pyglet.resource.animation(ag_file)
sprite = pyglet.sprite.Sprite(animation)

# create a window and set it to the image size
win = pyglet.window.Window(width=sprite.width, height=sprite.height)

# set window background color = r, g, b, alpha
# each value goes from 0.0 to 1.0
green = 0, 1, 0, 1
pyglet.gl.glClearColor(*green)

@win.event
def on_draw():
    win.clear()
    sprite.draw()

pyglet.app.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pyglet
#       3 # pick an animated gif file you have in the working directory
#       4 ag_file = "skull.gif"
#
# ModuleNotFoundError: No module named 'pyglet'

# %%
from PIL import Image
 
# 이미지 열기
im = Image.open('python.png')
 
# 이미지 크기 출력
print(im.size)
 
# 이미지 JPG로 저장
im.save('python.jpg')

# %%
from PIL import Image
 
im = Image.open('python.png')
 
# Thumbnail 이미지 생성
size = (64, 64)
im.thumbnail(size)  
 
im.save('python-thumb.jpg')

# %%
from PIL import Image
im = Image.open('python.png')
cropImage = im.crop((100, 100, 150, 150))
cropImage.save('python-crop.jpg')

# %%
from PIL import Image
im = Image.open('python.png')
 
# 크기를 600x600 으로
img2 = im.resize((600, 600))
img2.save('python-600.jpg')
 
# 90도 회전
img3 = im.rotate(90)
img3.save('python-rotate.jpg')

# %%
from PIL import Image, ImageFilter
 
im = Image.open('python.png')
blurImage = im.filter(ImageFilter.BLUR)
 
blurImage.save('python-blur.png')

# %%
import plistlib
#import debug_log
#from pprint import pprint as pp
#from rich import print


fileName = "./f3_fx_entropicdecay.plist"
pl = dict()
with open(fileName, 'rb') as fp:
    pl = plistlib.load(fp)
    
    print(type(pl))
    
for key, val in pl['metadata'].items():
    print("key = {key}, value={value}".format(key=key,value=val))
    
for item in pl['frames'].values():
    for key, val in item.items() : 
        print("key = {key}, value={value}".format(key=key,value=val))
        
        
# for val in pl.values():
#     pp(val)
    
# for key, val in pl.items():
#     pp("key = {key}, value={value}".format(key=key,value=val))
#     pl.
    
    
# for i in pl : 
#     pp(pl[i].values())
#     pp("key = {key}, value={value}".format(pl[i].keys(),pl[i].values()))
# Out:
# <class 'dict'>
# key = format, value=2
# key = size, value={512,1024}
# key = textureFileName, value=f3_fx_entropicdecay.png
# key = frame, value={{101,606},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{303,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{303,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,909},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,808},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,707},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,606},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,505},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,404},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,303},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{202,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,909},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,808},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,707},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{303,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,505},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,404},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,303},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{101,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,909},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,808},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,707},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,606},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,505},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,404},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,303},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,202},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,101},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
# key = frame, value={{0,0},{100,100}}
# key = offset, value={0,0}
# key = rotated, value=False
# key = sourceColorRect, value={{0,0},{100,100}}
# key = sourceSize, value={100,100}
